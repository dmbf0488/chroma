# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd

# %%
read_csv = r'chromatographicData.csv'
data = pd.read_csv(read_csv,skiprows=[0,1,2,10,11])

# %%
data1 = data.loc[0:4]
data1
# Out:
#    Retention Time  Raw MS1 Scan Abundance  Fitted Gaussian  1061.416232  \
# 0      830.596516                   106.0       117.039094        151.0
# 1      832.855675                   414.0       410.398442        446.0
# 2      835.126561                  1091.0      1093.484575        580.0
# 3      837.385380                   543.0       537.985623        216.0
# 4      839.647079                   104.0       130.024820          0.0
#
#    Unnamed: 4
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
data1.columns
# Out:
# Index(['Retention Time', 'Raw MS1 Scan Abundance', 'Fitted Gaussian',
#        '1061.416232', 'Unnamed: 4'],
#       dtype='object')

# %%
data1.plot.line(x='Retention Time',y=['Raw MS1 Scan Abundance','Fitted Gaussian'],marker='o')
plt.title('Chromatographic Data')
# Out:
# Text(0.5, 1.0, 'Chromatographic Data')

# %%
data2 = pd.read_csv(read_csv,skiprows=np.arange(0,11,1))
data2
# Out:
#    Retention Time  Raw MS1 Scan Abundance  Fitted Gaussian  1061.416427  \
# 0      828.225406                     238       396.242606          120
# 1      830.490596                    1347      1479.069109         1076
# 2      832.754102                    4329      4200.335765         4386
# 3      835.057219                    5789      5834.684926         6449
# 4      837.355832                    3599      3666.916829         4984
# 5      839.645555                    1348      1147.605909         1234
# 6      841.899767                     218       332.370185          295
#
#    1061.920759
# 0          124
# 1          641
# 2         2862
# 3         4055
# 4         2884
# 5          578
# 6           57

# %%
data2.columns
# Out:
# Index(['Retention Time', 'Raw MS1 Scan Abundance', 'Fitted Gaussian',
#        '1061.416427', '1061.920759'],
#       dtype='object')

# %%
data2.plot.line(x='Retention Time', y=['Raw MS1 Scan Abundance','Fitted Gaussian'], marker='o')
# Out:
# <Axes: xlabel='Retention Time'>
